# %% [markdown]
# # DataFrame

# %%
import pandas as pd

# %%
myList = [['Apel', 'Merah'],
          ['Pisang', 'Kuning'],
          ['Jeruk', 'Orange'] ]

# %%
myDataFrame = pd.DataFrame(myList)
myDataFrame
# Out:
#         0       1
# 0    Apel   Merah
# 1  Pisang  Kuning
# 2   Jeruk  Orange

# %%
myDF = pd.DataFrame(myList, columns=['Buah', 'Warna'])
myDF
# Out:
#      Buah   Warna
# 0    Apel   Merah
# 1  Pisang  Kuning
# 2   Jeruk  Orange

# %% [markdown]
# Membuat DataFrame dari lists

# %%
import pandas as pd
import numpy as np

# %%
myList = np.array([[0,1],
                  [2,3],
                  [4,5]])

# %%
myDataFrame = pd.DataFrame(myList, columns=['genap', 'ganjil'])
myDataFrame
# Out:
#    genap  ganjil
# 0      0       1
# 1      2       3
# 2      4       5

# %% [markdown]
# Membuat DataFrame dari dictionary

# %%
import pandas as pd
import numpy as npa

# %%
myDictionary = {'Buah':['Apel','Pisang','Jeruk'],
               'Warna':['Merah','Kuning','Orange']}

# %%
myDataFrame = pd.DataFrame(myDictionary)
myDataFrame
# Out:
#      Buah   Warna
# 0    Apel   Merah
# 1  Pisang  Kuning
# 2   Jeruk  Orange

# %% [markdown]
# Load CSV

# %%
import pandas as pd

# %%
df = pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %% [markdown]
# Mengubah index kolom

# %%
df.set_index('name')
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name', inplace=True)

# %%
df
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df.head()
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843

# %%
df.tail()
# Out:
#                          calories  protein  vitamins     rating
# name
# Apple Cinnamon Cheerios       110        2        25  29.509541
# Apple Jacks                   110        2        25  33.174094
# Basic 4                       130        3        25  37.038562
# Bran Chex                      90        2        25  49.120253
# Bran Flakes                    90        3        25  53.313813

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %%
df[1:4]
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df = pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df[['name','rating']]
# Out:
#                         name     rating
# 0                  100% Bran  68.402973
# 1          100% Natural Bran  33.983679
# 2                   All-Bran  59.425505
# 3  All-Bran with Extra Fiber  93.704912
# 4             Almond Delight  34.384843
# 5    Apple Cinnamon Cheerios  29.509541
# 6                Apple Jacks  33.174094
# 7                    Basic 4  37.038562
# 8                  Bran Chex  49.120253
# 9                Bran Flakes  53.313813

# %% [markdown]
# Memfilter Baris

# %%
df = df[0:5]
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
thirdRow = [False, False, True, False, False]
df[thirdRow]
# Out:
#        name  calories  protein  vitamins     rating
# 2  All-Bran        70        4        25  59.425505

# %%
df = pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df[(df['calories'] > 70) & (df['protein'] < 4)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %% [markdown]
# Filter loc & iloc

# %%
df = pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.loc[[0],['name']]
# Out:
#         name
# 0  100% Bran

# %%
df.loc[0:4,'name':'protein']
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.loc[[5,8],'name':'protein']
# Out:
#                       name  calories  protein
# 5  Apple Cinnamon Cheerios       110        2
# 8                Bran Chex        90        2

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.iloc[9,2]
# Out:
# 3

# %%
df.iloc[0:5, 0:3]
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.iloc[[0,2,4], 3]
# Out:
# 0    25
# 2    25
# 4    25
# Name: vitamins, dtype: int64

# %% [markdown]
# Menambah dan mengurangi baris dan kolom

# %%
df1 = df[0:5]
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df1.loc[6] = ['Trix',110,1,25,27.753302]
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 6                       Trix       110        1        25  27.753302

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.drop(2, axis=0, inplace=True)
df.drop(3, axis=0, inplace=True)
df
# Out:
#                       name  calories  protein  vitamins     rating
# 0                100% Bran        70        4        25  68.402973
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df['MyColumns'] = ['A','B','C','D','E','F','G','H']
df
# Out:
#                       name  calories  protein  vitamins     rating MyColumns
# 0                100% Bran        70        4        25  68.402973         A
# 1        100% Natural Bran       120        3         0  33.983679         B
# 4           Almond Delight       110        2        25  34.384843         C
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541         D
# 6              Apple Jacks       110        2        25  33.174094         E
# 7                  Basic 4       130        3        25  37.038562         F
# 8                Bran Chex        90        2        25  49.120253         G
# 9              Bran Flakes        90        3        25  53.313813         H

# %% [markdown]
# Mengurutkan nilai

# %%
df
# Out:
#                       name  calories  protein  vitamins     rating
# 0                100% Bran        70        4        25  68.402973
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.sort_values(by='calories')
# Out:
#                       name  calories  protein  vitamins     rating
# 0                100% Bran        70        4        25  68.402973
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 1        100% Natural Bran       120        3         0  33.983679
# 7                  Basic 4       130        3        25  37.038562

# %%
df.sort_values(by='calories', ascending=False)
# Out:
#                       name  calories  protein  vitamins     rating
# 7                  Basic 4       130        3        25  37.038562
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813
# 0                100% Bran        70        4        25  68.402973

# %%
df.to_csv('myFile.csv', index_label = False)

# %%
myFile = pd.read_csv('myFile.csv')
myFile
# Out:
#                       name  calories  protein  vitamins     rating
# 0                100% Bran        70        4        25  68.402973
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %% [markdown]
# Menggabungkan baris dan kolom

# %%
df1 = df[0:3]
df1 = df1.reset_index(drop=True)
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2     Almond Delight       110        2        25  34.384843

# %%
df2 = df[5:8]
df2 = df2.reset_index(drop=True)
df2
# Out:
#           name  calories  protein  vitamins     rating
# 0      Basic 4       130        3        25  37.038562
# 1    Bran Chex        90        2        25  49.120253
# 2  Bran Flakes        90        3        25  53.313813

# %%
pd.concat([df1,df2], axis=1)
# Out:
#                 name  calories  protein  vitamins     rating         name  \
# 0          100% Bran        70        4        25  68.402973      Basic 4
# 1  100% Natural Bran       120        3         0  33.983679    Bran Chex
# 2     Almond Delight       110        2        25  34.384843  Bran Flakes
#
#    calories  protein  vitamins     rating
# 0       130        3        25  37.038562
# 1        90        2        25  49.120253
# 2        90        3        25  53.313813

# %% [markdown]
# Split data

# %%
df = pd.DataFrame({'Gender': ['Female', 'Male',
                              'Female', 'Male'],
                   'Score': [85, 88, 95, 80]})
df
# Out:
#    Gender  Score
# 0  Female     85
# 1    Male     88
# 2  Female     95
# 3    Male     80

# %%
df.groupby(df['Gender']).mean()
# Out:
#         Score
# Gender
# Female   90.0
# Male     84.0
